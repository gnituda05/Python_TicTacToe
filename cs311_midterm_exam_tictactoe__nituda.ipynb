# %% [markdown]
# <a href="https://colab.research.google.com/github/gnituda05/Python_TicTacToe/blob/main/cs311_midterm_exam_tictactoe__nituda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import *
import threading

def worker(number):
    print ('I am thread: ' + str(number) + '\n')

thread_list = []
for i in range(4):
    thread = threading.Thread(target=worker, args=(i,))
    thread_list.append(thread)
    thread.start()
# Out:
# I am thread: 0
#
# I am thread: 1
#
# I am thread: 2
#
# I am thread: 3

# %% [markdown]
# # **Create a tic-tac-toe game in a console environment and include a background timer. **

# %%
from time import *
import threading
import numpy as np
import time	
player=[]
score=[0,0]
P1 = input('Player 1 name: ')
player.append(P1)
P2 = input('Player 2 name: ')
player.append(P2)



   
def insertLetter(letter, pos):
    board[pos] = letter
def spaceIsFree(pos):
        return board[pos] == ' '
def printBoard(board):
    
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])

    print('-----------')

    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])

    print('-----------')

    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])    
    
def isWinner(bo, le):
    return (bo[7] == le and bo[8] == le and bo[9] == le) or (bo[4] == le and bo[5] == le and bo[6] == le) or(bo[1] == le and bo[2] == le and bo[3] == le) or(bo[1] == le and bo[4] == le and bo[7] == le) or(bo[2] == le and bo[5] == le and bo[8] == le) or(bo[3] == le and bo[6] == le and bo[9] == le) or(bo[1] == le and bo[5] == le and bo[9] == le) or(bo[3] == le and bo[5] == le and bo[7] == le)




def playerMove1():
    run = True
    while run: 
        print('Player 1: ',player[0])
        move = input('Please select a position to place an \'X\' (1-9): ')
        try:
            move = int(move)
            if move > 0 and move < 10:
                if spaceIsFree(move):
                    run = False
                    insertLetter('X', move)
                else:
                    print('Sorry, this space is occupied!')
            else:
                print('Please type a number within the range!')
        except:
            print('Please type a number!')
        

def playerMove2():
  
    run = True
    while run:
        print('Player 2: ',player[1])
        move = input('Please select a position to place an \'O\' (1-9): ')
        try:
            move = int(move)
            if move > 0 and move < 10:
                if spaceIsFree(move):
                    run = False
                    insertLetter('O', move)
                else:
                    print('Sorry, this space is occupied!')
            else:
                print('Please type a number within the range!')
        except:
            print('Please type a number!')
  

def isBoardFull(board):
        if board.count(' ') > 1:
            return False
        else:
            return True
def main(self):
  
      print('Welcome to Tic Tac Toe!')
      print('Please select position by typing in a number between 1 to 9, see below for which number that is which position...'  
                      '\n 7 | 8 | 9'
                      '\n 4 | 5 | 6'
                      '\n 1 | 2 | 3'
                      '\n \n This Game is race to 3'
                       ' \n Goodluck! ')
      print('-----------------------------------')
      printBoard(board)
      tic = time.perf_counter()

      while not(isBoardFull(board)):
          if not(isWinner(board, 'O')):
              playerMove1()
              printBoard(board)
          else:
              print(player[1], ' Won this round!')
              toc = time.perf_counter() 
              print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
              score[1]= score[1] + 1
              if score[1]== 3:
                print("7In race to 3 ",player[1], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
              elif score[1]== 6:
                print(" In race to 3 ",player[1], " Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[1]== 9:
                print(" In race to 3 ",player[1], " Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break 
              elif score[1]== 12:
                print("In race to 3 ",player[1], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break  
              elif score[1]== 15:
                print("In race to 3 ",player[1], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[1]== 18:
                print("In race to 3 ",player[1], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[1]== 21:
                print("In race to 3 ",player[1], "Won it!!") 
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")  
                break
              break
              
          

          if not(isWinner(board, 'X')):
              playerMove2()
              printBoard(board)
          else:
              print(player[0],' Won this Round!')
              toc = time.perf_counter() 
              print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
              
              score[0]= score[0] + 1
              if score[0]== 3:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[0]== 6:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[0]== 9:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break 
              elif score[0]== 12:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break  
              elif score[0]== 15:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[0]== 18:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break
              elif score[0]== 21:
                print("In race to 3 ",player[0], "Won it!!")
                toc = time.perf_counter() 
                print(f"This Round finished in {(toc - tic)/60:0.0f} minutes {(toc - tic)%60:0.0f} seconds")
                break  
              break
              
              

      if isBoardFull(board):
          print('Tie Game!')


thread_list = []
if __name__ == "__main__":
    board = [' ' for x in range(10)]
    
    thread = threading.Thread(target=main, args=(10,))
    thread_list.append(thread)
    thread.start()
    thread.join()
    for x in range(10000):    
      answer = input('Do you want to play again? (Y/N)')
      if answer.lower() == 'y' or answer.lower == 'yes':

          board = [' ' for x in range(10)]     
          thread = threading.Thread(target=main, args=(10,))  
          thread.start()
          thread.join()    
      elif answer.lower() == 'n' or answer.lower == 'no':
        break
# Out:
# Player 1 name: Glenn
# Player 2 name: Jude
# Welcome to Tic Tac Toe!
# Please select position by typing in a number between 1 and 9, see below for which number that is which position...
#  7 | 8 | 9
#  4 | 5 | 6
#  1 | 2 | 3
#
#  This Game is race to 3
#  Goodluck!
# -----------------------------------
#    |   |
# -----------
#    |   |
# -----------
#    |   |
# Player 1:  Glenn
# Please select a position to place an 'X' (1-9): 7
#  X |   |
# -----------
#    |   |
# -----------
#    |   |
# Player 2:  Jude
# Please select a position to place an 'O' (1-9): 3
#  X |   |
# -----------
#    |   |
# -----------
#    |   | O
# Player 1:  Glenn
# Please select a position to place an 'X' (1-9): 6
#  X |   |
# -----------
#    |   | X
# -----------
#    |   | O
# Player 2:  Jude
# Please select a position to place an 'O' (1-9): 2
#  X |   |
# -----------
#    |   | X
# -----------
#    | O | O
# Player 1:  Glenn
# Please select a position to place an 'X' (1-9): 5
#  X |   |
# -----------
# ...
